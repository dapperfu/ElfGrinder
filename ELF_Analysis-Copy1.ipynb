# %%
import get_files
import os

# %%
__here__ = os.path.abspath(".")

# %%
os.chdir("Blink/")

# %%
import subprocess

# %%
subprocess.check_output(["make"])
# Out:
# b'-------------------------\nArduino.mk Configuration:\n- [AUTODETECTED]       CURRENT_OS = LINUX \n- [USER]               ARDUINO_DIR = /projects/ElfGrinder/arduino \n- [USER]               ARDMK_DIR = /projects/ElfGrinder/arduino_make \n- [DEFAULT]            ARDUINO_VERSION = 100 \n- [USER]               ARCHITECTURE = avr \n- [DEFAULT]            ARDMK_VENDOR = arduino \n- [AUTODETECTED]       ARDUINO_PREFERENCES_PATH = /home/jed/.arduino/preferences.txt \n- [AUTODETECTED]       ARDUINO_SKETCHBOOK = /home/jed/sketchbook (from arduino preferences file)\n- [AUTODETECTED]       AVR_TOOLS_DIR = /usr (found in $PATH)\n- [COMPUTED]           ARDUINO_LIB_PATH = /projects/ElfGrinder/arduino/libraries (from ARDUINO_DIR)\n- [COMPUTED]           ARDUINO_VAR_PATH = /projects/ElfGrinder/arduino/hardware/arduino/avr/variants (from ARDUINO_DIR)\n- [COMPUTED]           BOARDS_TXT = /projects/ElfGrinder/arduino/hardware/arduino/avr/boards.txt (from ARDUINO_DIR)\n- [DEFAULT]            USER_LIB_PATH = /home/jed/sketchbook/libraries (in user sketchbook)\n- [DEFAULT]            PRE_BUILD_HOOK = pre-build-hook.sh \n- [DEFAULT]            BOARD_TAG = uno \n- [COMPUTED]           CORE = arduino (from build.core)\n- [COMPUTED]           VARIANT = standard (from build.variant)\n- [COMPUTED]           OBJDIR = build-uno (from BOARD_TAG)\n- [COMPUTED]           ARDUINO_CORE_PATH = /projects/ElfGrinder/arduino/hardware/arduino/avr/cores/arduino (from ARDUINO_DIR, BOARD_TAG and boards.txt)\n- [USER]               MONITOR_BAUDRATE = 115200 \n- [DEFAULT]            OPTIMIZATION_LEVEL = s \n- [DEFAULT]            MCU_FLAG_NAME = mmcu \n- [DEFAULT]            CFLAGS_STD = -std=gnu11 -flto -fno-fat-lto-objects \n- [DEFAULT]            CXXFLAGS_STD = -std=gnu++11 -fno-threadsafe-statics -flto \n- [AUTODETECTED]       DEVICE_PATH =  \n- [DEFAULT]            FORCE_MONITOR_PORT =  \n- [AUTODETECTED]       Size utility: AVR-aware for enhanced output\n- [COMPUTED]           BOOTLOADER_PARENT = /projects/ElfGrinder/arduino/hardware/arduino/avr/bootloaders (from ARDUINO_DIR)\n- [COMPUTED]           ARDMK_VERSION = 1.5 \n- [COMPUTED]           CC_VERSION = 5.4.0 (avr-gcc)\n-------------------------\nInfo: pre-build-hook.sh success\nmkdir -p build-uno\n'

# %%
os.chdir(__here__)

# %%
ELFS = get_files.get_files("Blink/", extensions=".elf")

# %%
ELFS
# Out:
# <generator object get_files at 0x7f5c4831d840>

# %%
for ELF in ELFS:
    break
ELF
# Out:
# '/projects/ElfGrinder/Blink/build-uno/Blink.elf'

# %%
from elftools.elf.elffile import ELFFile

# %%
def process_file(filename):
    print('In file:', filename)
    with open(filename, 'rb') as f:
        elffile = ELFFile(f)

        for section in elffile.iter_sections():
            print(f"  {section.name}")

# %%
process_file(ELF)
# Out:
# In file: /projects/ElfGrinder/Blink/build-uno/Blink.elf
#
#   .data
#   .text
#   .bss
#   .comment
#   .note.gnu.avr.deviceinfo
#   .debug_info
#   .debug_abbrev
#   .debug_line
#   .debug_str
#   .shstrtab
#   .symtab
#   .strtab

# %%
with open(filename, 'rb') as f:
    elffile = ELFFile(f)

    for section in elffile.iter_sections():
        print(f"  {section.name}")

    data = elffile.get_section_by_name(".data")
    print(data.data())
# Out:
#
#   .data
#   .text
#   .bss
#   .comment
#   .note.gnu.avr.deviceinfo
#   .debug_info
#   .debug_abbrev
#   .debug_line
#   .debug_str
#   .shstrtab
#   .symtab
#   .strtab
# b'\r\x00\x00\x00\x00\xe5\x00b\x01\x87\x00,\x01\xb8\x00\x96\x00\xaa\x00Pin: \x00\r\n\x00'

# %%
f = open(filename, 'rb')
elffile = ELFFile(f)

for section in elffile.iter_sections():
    print(f"  {section.name}")

data = elffile.get_section_by_name(".data")
print(data.data())
# Out:
#
#   .data
#   .text
#   .bss
#   .comment
#   .note.gnu.avr.deviceinfo
#   .debug_info
#   .debug_abbrev
#   .debug_line
#   .debug_str
#   .shstrtab
#   .symtab
#   .strtab
# b'\r\x00\x00\x00\x00\xe5\x00b\x01\x87\x00,\x01\xb8\x00\x96\x00\xaa\x00Pin: \x00\r\n\x00'

# %%
elffile.get_section_by_name(".symtab").data()
# Out:
# b"\t\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\xf1\xff\x01\x00\x00\x00>\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf1\xff\n\x00\x00\x00=\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf1\xff\x13\x00\x00\x00?\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf1\xff\x1c\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf1\xff(\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf1\xff5\x00\x00\x00\x0e\x01\x00\x00\x1e\x00\x00\x00\x02\x00\x02\x00^\x00\x00\x00,\x01\x00\x00(\x00\x00\x00\x02\x00\x02\x00y\x00\x00\x00T\x01\x00\x00\x1c\x00\x00\x00\x02\x00\x02\x00\x94\x00\x00\x00p\x01\x00\x00\x18\x00\x00\x00\x02\x00\x02\x00\xb4\x00\x00\x00\x88\x01\x00\x00B\x00\x00\x00\x02\x00\x02\x00\xdd\x00\x00\x00\xca\x01\x00\x00\x8e\x00\x00\x00